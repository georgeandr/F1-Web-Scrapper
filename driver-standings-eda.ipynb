# %%
import numpy as np
import pandas as pd
import seaborn as sns
import pycountry
from matplotlib import pyplot as plt
import plotly
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as pyo
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
standings_df = pd.read_csv('driver_stangings.csv', delimiter = ';')
standings_df
# Out:
#      Pos                  Driver Nationality                       Car    PTS  \
# 0      1      Max Verstappen VER         NED     Red Bull Racing Honda  395.5
# 1      2      Lewis Hamilton HAM         GBR                  Mercedes  387.5
# 2      3     Valtteri Bottas BOT         FIN                  Mercedes  226.0
# 3      4        Sergio Perez PER         MEX     Red Bull Racing Honda  190.0
# 4      5        Carlos Sainz SAI         ESP                   Ferrari  164.5
# ...   ..                     ...         ...                       ...    ...
# 1591  13  Philippe Etancelin ETA         FRA                       NaN    3.0
# 1592  19      Felice Bonetto BON         ITA           Maserati Milano    2.0
# 1593  20   Tony Bettenhausen BET         USA         Deidt Offenhauser    1.0
# 1594  20       Joie Chitwood CHI         USA  Kurtis Kraft Offenhauser    1.0
# 1595  20      Eugene Chaboud CHA         FRA                       NaN    1.0
#
#                        Year
# ...

# %%
standings_df['Year'] = standings_df['Year'].str.rstrip(' Driver Standings')
standings_df.head(10)
# Out:
#   Pos                Driver Nationality                    Car    PTS  Year
# 0   1    Max Verstappen VER         NED  Red Bull Racing Honda  395.5  2021
# 1   2    Lewis Hamilton HAM         GBR               Mercedes  387.5  2021
# 2   3   Valtteri Bottas BOT         FIN               Mercedes  226.0  2021
# 3   4      Sergio Perez PER         MEX  Red Bull Racing Honda  190.0  2021
# 4   5      Carlos Sainz SAI         ESP                Ferrari  164.5  2021
# 5   6      Lando Norris NOR         GBR       McLaren Mercedes  160.0  2021
# 6   7   Charles Leclerc LEC         MON                Ferrari  159.0  2021
# 7   8  Daniel Ricciardo RIC         AUS       McLaren Mercedes  115.0  2021
# 8   9      Pierre Gasly GAS         FRA       AlphaTauri Honda  110.0  2021
# 9  10   Fernando Alonso ALO         ESP         Alpine Renault   81.0  2021

# %%
def annually_drivers_points(df, year):
    year_df = df.loc[df['Year'] == year]
    f, ax = plt.subplots(figsize=(10, 5))
    ax = sns.barplot(data = year_df, x = 'Driver', y = 'PTS', palette = 'rocket')
    ax = plt.xticks(rotation = 70)
    ax = plt.ylabel('Points Scored in %s' %year)
    ax = plt.xlabel('Driver\'s Name')
    plt.title("Drivers Points of %s" %year)

# %%
annually_drivers_points(standings_df, '2021')

# %%
def driver_points(df, name):
    df_name = df.loc[df['Driver'] == name]
    f, ax = plt.subplots(figsize=(10, 5))
    ax = sns.barplot(data = df_name, x = 'Year', y = 'PTS', palette = 'viridis')
    ax = plt.xticks(rotation = 70)
    ax = plt.ylabel('Points Scored')
    ax = plt.xlabel('Driver\'s Name')
    plt.title("Points of %s" %name + "scored from the beggining of his career")

# %%
driver_points(standings_df, 'Lewis Hamilton HAM')

# %%
standings_df.groupby(['Driver','Nationality']).size().count('Nationality')
# Out:
# /var/folders/p3/0hxxs9qj1dg_s5vjw8zddyw40000gn/T/ipykernel_10665/526525298.py:1: FutureWarning:
#
# Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. ser.count(level=1) should use ser.groupby(level=1).count().
# Nationality
# ARG     9
# AUS     5
# AUT     7
# BEL     9
# BRA    24
# CAN     5
# CHI     1
# COL     1
# DEN     3
# ESP     9
# FIN     7
# FRA    40
# GBR    70
# GER    22
# HUN     1
# INA     1
# IND     2
# IRL     2
# ITA    51
# JPN    11
# MAS     1
# MEX     6
# MON     3
# NED     8
# NZL     5
# POL     1
# POR     3
# RAF     1
# RHO     2
# RSA     8
# RUS     3
# SUI     7
# SWE     7
# THA     2
# USA    55
# VEN     2
# dtype: int64
